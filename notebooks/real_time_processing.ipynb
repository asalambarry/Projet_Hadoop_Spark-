# %%
from pyspark.sql.types import StructType, StructField, IntegerType, FloatType, TimestampType
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.ml.recommendation import ALSModel
from kafka import KafkaProducer
import json
import time
import random


# Configuration Spark
spark = SparkSession.builder \
    .appName("RealTimeRecommendations") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.0") \
    .getOrCreate()

# %%
# Configuration Kafka
KAFKA_BROKER = 'bigdata-container:9092'
TOPIC_NAME = 'movieratings'

# Création du producer
producer = KafkaProducer(
    bootstrap_servers=KAFKA_BROKER,
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Génération de données
def generate_rating():
    return {
        'userId': random.randint(1, 1000),
        'movieId': random.randint(1, 1000),
        'rating': round(random.uniform(0.5, 5.0), 1),
        'timestamp': int(time.time())
    }

# Envoi des messages
for _ in range(50): 
    message = generate_rating()
    producer.send(TOPIC_NAME, message)
    print(f"Message envoyé: {message}")
    time.sleep(1)
# Out:
# Message envoyé: {'userId': 116, 'movieId': 470, 'rating': 1.6, 'timestamp': 1746182741}
# Message envoyé: {'userId': 336, 'movieId': 628, 'rating': 0.8, 'timestamp': 1746182742}
# -------------------------------------------
# Batch: 136
# -------------------------------------------
# -------------------------------------------
# Batch: 90
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   116|    470| 0.9257184|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   116|    470| 0.9257184|
# +------+-------+----------+
#
# Message envoyé: {'userId': 34, 'movieId': 82, 'rating': 2.8, 'timestamp': 1746182743}
# -------------------------------------------
# Batch: 137
# -------------------------------------------
# -------------------------------------------
# Batch: 91
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   336|    628| 3.6745968|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   336|    628| 3.6745968|
# +------+-------+----------+
#
# Message envoyé: {'userId': 461, 'movieId': 579, 'rating': 1.3, 'timestamp': 1746182744}
# -------------------------------------------
# Batch: 92
# -------------------------------------------
# -------------------------------------------
# Batch: 138
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    34|     82|  4.236392|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    34|     82|  4.236392|
# +------+-------+----------+
#
# Message envoyé: {'userId': 282, 'movieId': 14, 'rating': 1.4, 'timestamp': 1746182745}
# -------------------------------------------
# Batch: 139
# -------------------------------------------
# -------------------------------------------
# Batch: 93
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   461|    579| 3.1514795|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   461|    579| 3.1514795|
# +------+-------+----------+
#
# Message envoyé: {'userId': 602, 'movieId': 936, 'rating': 4.9, 'timestamp': 1746182746}
# -------------------------------------------
# Batch: 140
# -------------------------------------------
# -------------------------------------------
# Batch: 94
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   282|     14| 3.4266598|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   282|     14| 3.4266598|
# +------+-------+----------+
#
# Message envoyé: {'userId': 227, 'movieId': 43, 'rating': 3.3, 'timestamp': 1746182747}
# -------------------------------------------
# Batch: 141
# -------------------------------------------
# -------------------------------------------
# Batch: 95
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   602|    936| 4.2348666|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   602|    936| 4.2348666|
# +------+-------+----------+
#
# Message envoyé: {'userId': 357, 'movieId': 327, 'rating': 3.1, 'timestamp': 1746182748}
# -------------------------------------------
# Batch: 142
# -------------------------------------------
# -------------------------------------------
# Batch: 96
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   227|     43|  2.568421|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   227|     43|  2.568421|
# +------+-------+----------+
#
# Message envoyé: {'userId': 223, 'movieId': 220, 'rating': 4.3, 'timestamp': 1746182749}
# -------------------------------------------
# Batch: 97
# -------------------------------------------
# -------------------------------------------
# Batch: 143
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   357|    327| 1.9684759|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   357|    327| 1.9684759|
# +------+-------+----------+
#
# Message envoyé: {'userId': 457, 'movieId': 457, 'rating': 5.0, 'timestamp': 1746182750}
# -------------------------------------------
# Batch: 144
# -------------------------------------------
# -------------------------------------------
# Batch: 98
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   223|    220| 1.5979125|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   223|    220| 1.5979125|
# +------+-------+----------+
#
# Message envoyé: {'userId': 604, 'movieId': 637, 'rating': 3.6, 'timestamp': 1746182751}
# -------------------------------------------
# Batch: 145
# -------------------------------------------
# -------------------------------------------
# Batch: 99
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   457|    457| 3.3518603|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   457|    457| 3.3518603|
# +------+-------+----------+
#
# Message envoyé: {'userId': 457, 'movieId': 629, 'rating': 4.9, 'timestamp': 1746182752}
# -------------------------------------------
# Batch: 100
# -------------------------------------------
# -------------------------------------------
# Batch: 146
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   604|    637| 2.5340278|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   604|    637| 2.5340278|
# +------+-------+----------+
# Message envoyé: {'userId': 535, 'movieId': 631, 'rating': 2.8, 'timestamp': 1746182753}
# -------------------------------------------
# Batch: 101
# -------------------------------------------
# -------------------------------------------
# Batch: 147
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   457|    629| 4.0739007|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   457|    629| 4.0739007|
# +------+-------+----------+
#
# Message envoyé: {'userId': 992, 'movieId': 366, 'rating': 4.8, 'timestamp': 1746182754}
# -------------------------------------------
# Batch: 102
# -------------------------------------------
# -------------------------------------------
# Batch: 148
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   535|    631| 1.5626397|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   535|    631| 1.5626397|
# +------+-------+----------+
#
# Message envoyé: {'userId': 219, 'movieId': 731, 'rating': 2.8, 'timestamp': 1746182755}
# -------------------------------------------
# Batch: 149
# -------------------------------------------
# -------------------------------------------
# Batch: 103
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   992|    366| 2.3926792|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   992|    366| 2.3926792|
# +------+-------+----------+
#
# Message envoyé: {'userId': 376, 'movieId': 798, 'rating': 2.9, 'timestamp': 1746182756}
# -------------------------------------------
# Batch: 150
# -------------------------------------------
# -------------------------------------------
# Batch: 104
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   219|    731|   2.31743|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   219|    731|   2.31743|
# +------+-------+----------+
#
# Message envoyé: {'userId': 85, 'movieId': 359, 'rating': 3.6, 'timestamp': 1746182757}
# -------------------------------------------
# Batch: 105
# -------------------------------------------
# -------------------------------------------
# Batch: 151
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   376|    798| 2.7205749|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   376|    798| 2.7205749|
# +------+-------+----------+
#
# Message envoyé: {'userId': 124, 'movieId': 746, 'rating': 3.6, 'timestamp': 1746182758}
# -------------------------------------------
# Batch: 106
# -------------------------------------------
# -------------------------------------------
# Batch: 152
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    85|    359| 3.8729167|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    85|    359| 3.8729167|
# +------+-------+----------+
#
# Message envoyé: {'userId': 785, 'movieId': 444, 'rating': 2.1, 'timestamp': 1746182759}
# -------------------------------------------
# Batch: 107
# -------------------------------------------
# -------------------------------------------
# Batch: 153
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   124|    746|  4.696412|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   124|    746|  4.696412|
# +------+-------+----------+
#
# Message envoyé: {'userId': 291, 'movieId': 48, 'rating': 1.2, 'timestamp': 1746182760}
# -------------------------------------------
# Batch: 154
# -------------------------------------------
# -------------------------------------------
# Batch: 108
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   785|    444| 1.0201063|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   785|    444| 1.0201063|
# +------+-------+----------+
#
# Message envoyé: {'userId': 279, 'movieId': 38, 'rating': 4.6, 'timestamp': 1746182761}
# -------------------------------------------
# Batch: 155
# -------------------------------------------
# -------------------------------------------
# Batch: 109
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   291|     48| 2.1691334|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   291|     48| 2.1691334|
# +------+-------+----------+
#
# Message envoyé: {'userId': 630, 'movieId': 104, 'rating': 2.3, 'timestamp': 1746182762}
# -------------------------------------------
# Batch: 110
# -------------------------------------------
# -------------------------------------------
# Batch: 156
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   279|     38| 3.6069605|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   279|     38| 3.6069605|
# +------+-------+----------+
#
# Message envoyé: {'userId': 837, 'movieId': 497, 'rating': 3.3, 'timestamp': 1746182763}
# -------------------------------------------
# Batch: 111
# -------------------------------------------
# -------------------------------------------
# Batch: 157
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   630|    104|  4.131141|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   630|    104|  4.131141|
# +------+-------+----------+
#
# Message envoyé: {'userId': 914, 'movieId': 907, 'rating': 4.3, 'timestamp': 1746182764}
# -------------------------------------------
# Batch: 112
# -------------------------------------------
# -------------------------------------------
# Batch: 158
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   837|    497| 4.7644224|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   837|    497| 4.7644224|
# +------+-------+----------+
#
# Message envoyé: {'userId': 307, 'movieId': 831, 'rating': 3.8, 'timestamp': 1746182765}
# -------------------------------------------
# Batch: 113
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   914|    907|  4.628333|
# +------+-------+----------+
#
# -------------------------------------------
# Batch: 159
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   914|    907|  4.628333|
# +------+-------+----------+
#
# Message envoyé: {'userId': 568, 'movieId': 952, 'rating': 2.8, 'timestamp': 1746182766}
# -------------------------------------------
# Batch: 160
# -------------------------------------------
# -------------------------------------------
# Batch: 114
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   307|    831| 3.3692403|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   307|    831| 3.3692403|
# +------+-------+----------+
#
# Message envoyé: {'userId': 107, 'movieId': 516, 'rating': 2.8, 'timestamp': 1746182767}
# -------------------------------------------
# Batch: 115
# -------------------------------------------
# -------------------------------------------
# Batch: 161
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   568|    952| 3.9887948|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   568|    952| 3.9887948|
# +------+-------+----------+
#
# Message envoyé: {'userId': 11, 'movieId': 746, 'rating': 2.0, 'timestamp': 1746182768}
# -------------------------------------------
# Batch: 116
# -------------------------------------------
# -------------------------------------------
# Batch: 162
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   107|    516| 3.6655838|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   107|    516| 3.6655838|
# +------+-------+----------+
#
# Message envoyé: {'userId': 919, 'movieId': 401, 'rating': 4.7, 'timestamp': 1746182769}
# -------------------------------------------
# Batch: 117
# -------------------------------------------
# -------------------------------------------
# Batch: 163
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    11|    746| 3.3280153|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    11|    746| 3.3280153|
# +------+-------+----------+
#
# Message envoyé: {'userId': 265, 'movieId': 390, 'rating': 0.8, 'timestamp': 1746182770}
# -------------------------------------------
# Batch: 118
# -------------------------------------------
# -------------------------------------------
# Batch: 164
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   919|    401|  3.259077|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   919|    401|  3.259077|
# +------+-------+----------+
#
# Message envoyé: {'userId': 503, 'movieId': 234, 'rating': 2.8, 'timestamp': 1746182771}
# -------------------------------------------
# Batch: 119
# -------------------------------------------
# -------------------------------------------
# Batch: 165
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   265|    390| 2.4678397|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   265|    390| 2.4678397|
# +------+-------+----------+
#
# Message envoyé: {'userId': 651, 'movieId': 220, 'rating': 3.6, 'timestamp': 1746182772}
# -------------------------------------------
# Batch: 120
# -------------------------------------------
# -------------------------------------------
# Batch: 166
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   503|    234| 2.1223335|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   503|    234| 2.1223335|
# +------+-------+----------+
#
# Message envoyé: {'userId': 709, 'movieId': 323, 'rating': 2.6, 'timestamp': 1746182773}
# -------------------------------------------
# Batch: 167
# -------------------------------------------
# -------------------------------------------
# Batch: 121
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   651|    220| 0.9699159|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   651|    220| 0.9699159|
# +------+-------+----------+
#
# Message envoyé: {'userId': 103, 'movieId': 266, 'rating': 1.5, 'timestamp': 1746182774}
# -------------------------------------------
# Batch: 122
# -------------------------------------------
# -------------------------------------------
# Batch: 168
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# +------+-------+----------+
#
# Message envoyé: {'userId': 320, 'movieId': 412, 'rating': 4.0, 'timestamp': 1746182775}
# -------------------------------------------
# Batch: 123
# -------------------------------------------
# -------------------------------------------
# Batch: 169
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   103|    266|  3.188211|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   103|    266|  3.188211|
# +------+-------+----------+
#
# Message envoyé: {'userId': 227, 'movieId': 108, 'rating': 2.6, 'timestamp': 1746182776}
# -------------------------------------------
# Batch: 170
# -------------------------------------------
# -------------------------------------------
# Batch: 124
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   320|    412| 2.6827652|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   320|    412| 2.6827652|
# +------+-------+----------+
#
# Message envoyé: {'userId': 505, 'movieId': 157, 'rating': 2.7, 'timestamp': 1746182777}
# -------------------------------------------
# Batch: 125
# -------------------------------------------
# -------------------------------------------
# Batch: 171
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   227|    108| 1.7884697|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   227|    108| 1.7884697|
# +------+-------+----------+
#
# Message envoyé: {'userId': 686, 'movieId': 476, 'rating': 2.3, 'timestamp': 1746182778}
# -------------------------------------------
# Batch: 126
# -------------------------------------------
# -------------------------------------------
# Batch: 172
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   505|    157|  3.569388|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   505|    157|  3.569388|
# +------+-------+----------+
#
# Message envoyé: {'userId': 87, 'movieId': 223, 'rating': 4.2, 'timestamp': 1746182779}
# -------------------------------------------
# Batch: 173
# -------------------------------------------
# -------------------------------------------
# Batch: 127
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   686|    476| 3.2543836|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   686|    476| 3.2543836|
# +------+-------+----------+
#
# Message envoyé: {'userId': 165, 'movieId': 617, 'rating': 4.4, 'timestamp': 1746182780}
# -------------------------------------------
# Batch: 128
# -------------------------------------------
# -------------------------------------------
# Batch: 174
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    87|    223| 2.9958918|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    87|    223| 2.9958918|
# +------+-------+----------+
#
# Message envoyé: {'userId': 499, 'movieId': 386, 'rating': 3.2, 'timestamp': 1746182781}
# -------------------------------------------
# Batch: 175
# -------------------------------------------
# -------------------------------------------
# Batch: 129
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   165|    617| 2.5420785|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   165|    617| 2.5420785|
# +------+-------+----------+
#
# Message envoyé: {'userId': 817, 'movieId': 530, 'rating': 3.2, 'timestamp': 1746182782}
# -------------------------------------------
# Batch: 130
# -------------------------------------------
# -------------------------------------------
# Batch: 176
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   499|    386| 3.8330977|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   499|    386| 3.8330977|
# +------+-------+----------+
# Message envoyé: {'userId': 67, 'movieId': 325, 'rating': 2.7, 'timestamp': 1746182783}
# -------------------------------------------
# Batch: 131
# -------------------------------------------
# -------------------------------------------
# Batch: 177
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   817|    530| 3.2780533|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   817|    530| 3.2780533|
# +------+-------+----------+
#
# Message envoyé: {'userId': 770, 'movieId': 220, 'rating': 1.8, 'timestamp': 1746182784}
# -------------------------------------------
# Batch: 178
# -------------------------------------------
# -------------------------------------------
# Batch: 132
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    67|    325| 2.4190583|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    67|    325| 2.4190583|
# +------+-------+----------+
#
# Message envoyé: {'userId': 609, 'movieId': 54, 'rating': 2.8, 'timestamp': 1746182785}
# -------------------------------------------
# Batch: 133
# -------------------------------------------
# -------------------------------------------
# Batch: 179
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   770|    220| 3.0789354|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   770|    220| 3.0789354|
# +------+-------+----------+
#
# Message envoyé: {'userId': 820, 'movieId': 942, 'rating': 1.4, 'timestamp': 1746182786}
# -------------------------------------------
# Batch: 134
# -------------------------------------------
# -------------------------------------------
# Batch: 180
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   609|     54| 1.1932445|
# +------+-------+----------+
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   609|     54| 1.1932445|
# +------+-------+----------+
#
# Message envoyé: {'userId': 22, 'movieId': 874, 'rating': 3.9, 'timestamp': 1746182787}
# -------------------------------------------
# Batch: 181
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   820|    942|   4.29988|
# +------+-------+----------+
#
# -------------------------------------------
# Batch: 135
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   820|    942|   4.29988|
# +------+-------+----------+
#
# Message envoyé: {'userId': 812, 'movieId': 528, 'rating': 4.7, 'timestamp': 1746182788}
# -------------------------------------------
# Batch: 182
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    22|    874|  3.953876|
# +------+-------+----------+
#
# Message envoyé: {'userId': 199, 'movieId': 8, 'rating': 0.9, 'timestamp': 1746182789}
# -------------------------------------------
# Batch: 136
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    22|    874|  3.953876|
# |   812|    528| 2.1853838|
# +------+-------+----------+
#
# -------------------------------------------
# Batch: 183
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   812|    528| 2.1853838|
# +------+-------+----------+
#
# Message envoyé: {'userId': 61, 'movieId': 885, 'rating': 0.8, 'timestamp': 1746182790}
# -------------------------------------------
# Batch: 137
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   199|      8| 3.1439137|
# +------+-------+----------+

# %%
# Schéma des messages
schema = StructType([
    StructField("userId", IntegerType(), True),
    StructField("movieId", IntegerType(), True),
    StructField("rating", FloatType(), True),
    StructField("timestamp", TimestampType(), True)
])

# Configuration du streaming Kafka
kafka_stream = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", KAFKA_BROKER) \
    .option("subscribe", TOPIC_NAME) \
    .load()

# Transformation des messages
parsed_stream = kafka_stream.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")

# Chargement du modèle et prédictions
model_path = "hdfs://namenode:9000/models/als_recommender"
als_model = ALSModel.load(model_path)
predictions = als_model.transform(parsed_stream)

# Configuration et démarrage du streaming
query = predictions.select("userId", "movieId", "rating") \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .start()

# Attente des résultats
query.awaitTermination(timeout=60)
# Out:
# -------------------------------------------
# Batch: 184
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |   199|      8| 3.1439137|
# |    61|    885| 2.0062792|
# +------+-------+----------+
#
# -------------------------------------------
# Batch: 138
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |    61|    885| 2.0062792|
# +------+-------+----------+
# 25/05/02 10:46:32 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-46fca008-1180-4be3-bf0d-a23bd1965bb9. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/05/02 10:46:32 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/05/02 10:46:32 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# +------+-------+----------+
# False
